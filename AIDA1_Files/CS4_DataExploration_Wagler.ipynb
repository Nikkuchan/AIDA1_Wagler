# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikkuchan/AIDA-Group8/blob/main/CS4_DataExploration_Wagler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
anime_df = pd.read_csv("Anime.csv")

# %%
anime_df
# Out:
#        animeID  ...                                            related
# 0            1  ...  {'Adaptation': [{'mal_id': 173, 'type': 'manga...
# 1            5  ...  {'Parent story': [{'mal_id': 1, 'type': 'anime...
# 2            6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 3            7  ...                                                 {}
# 4            8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
# ...        ...  ...                                                ...
# 15273    39195  ...  {'Adaptation': [{'mal_id': 103701, 'type': 'ma...
# 15274    39196  ...  {'Adaptation': [{'mal_id': 104241, 'type': 'ma...
# 15275    39197  ...                                                 {}
# 15276    39198  ...  {'Adaptation': [{'mal_id': 98578, 'type': 'man...
# 15277    39199  ...  {'Adaptation': [{'mal_id': 72117, 'type': 'man...
#
# [15278 rows x 27 columns]

# %%
anime_df.head(5)
# Out:
#    animeID  ...                                            related
# 0        1  ...  {'Adaptation': [{'mal_id': 173, 'type': 'manga...
# 1        5  ...  {'Parent story': [{'mal_id': 1, 'type': 'anime...
# 2        6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 3        7  ...                                                 {}
# 4        8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
#
# [5 rows x 27 columns]

# %%
anime_df.tail(5)
# Out:
#       animeID  ...                                            related
# 4809     7456  ...  {'Sequel': [{'mal_id': 2432, 'type': 'anime', ...
# 4810     7458  ...  {'Adaptation': [{'mal_id': 69341, 'type': 'man...
# 4811     7459  ...                                                 {}
# 4812     7461  ...  {'Parent story': [{'mal_id': 7547, 'type': 'an...
# 4813     7463  ...                                                NaN
#
# [5 rows x 27 columns]

# %%
anime_df.describe()
# Out:
#            animeID     episodes  ...       members      favorites
# count  4814.000000  4800.000000  ...  4.808000e+03    4808.000000
# mean   3129.458247    15.824583  ...  2.828362e+04     500.018303
# std    2057.791222    45.101853  ...  8.838861e+04    3838.451037
# min       1.000000     1.000000  ...  1.440000e+02       0.000000
# 25%    1411.250000     1.000000  ...  1.320250e+03       2.000000
# 50%    2775.500000     3.000000  ...  3.789500e+03       8.000000
# 75%    4774.750000    23.250000  ...  1.643250e+04      49.000000
# max    7463.000000  1787.000000  ...  1.610561e+06  120331.000000
#
# [8 rows x 8 columns]

# %%
anime_df.dtypes
# Out:
# animeID              int64
#  name               object
#  title_english      object
#  title_japanese     object
#  title_synonyms     object
#  type               object
#  source             object
#  producers          object
#  genre              object
#  studio             object
#  episodes          float64
#  status             object
#  airing             object
#  aired              object
#  duration           object
#  rating             object
#  score             float64
#  scored_by         float64
#  rank              float64
#  popularity        float64
#  members           float64
#  favorites         float64
#  synopsis           object
#  background         object
#  premiered          object
#  broadcast          object
#  related            object
# dtype: object

# %%
#features of the dataset 
anime_df.columns
# Out:
# Index(['animeID', ' name', ' title_english', ' title_japanese',
#        ' title_synonyms', ' type', ' source', ' producers', ' genre',
#        ' studio', ' episodes', ' status', ' airing', ' aired', ' duration',
#        ' rating', ' score', ' scored_by', ' rank', ' popularity', ' members',
#        ' favorites', ' synopsis', ' background', ' premiered', ' broadcast',
#        ' related'],
#       dtype='object')

# %%
anime_df[' episodes'].sum()
# Out:
# 75958.0

# %%
#Data Splicing
popular_anime = anime_df[[' name',' popularity',' status', ' score',' episodes',' favorites']]
popular_anime
# Out:
#                                     name   popularity  ...  episodes   favorites
# 0                           Cowboy Bebop         39.0  ...      26.0     43460.0
# 1        Cowboy Bebop: Tengoku no Tobira        449.0  ...       1.0       776.0
# 2                                 Trigun        146.0  ...      26.0     10432.0
# 3                     Witch Hunter Robin       1171.0  ...      26.0       537.0
# 4                         Bouken Ou Beet       3704.0  ...      52.0        14.0
# ...                                  ...          ...  ...       ...         ...
# 15273                           Beastars      14917.0  ...       NaN         0.0
# 15274            Mairimashita! Iruma-kun      15231.0  ...       NaN         0.0
# 15275             Karrimor Mountain Club      15424.0  ...       4.0         0.0
# 15276                    Kanata no Astra          0.0  ...       NaN         2.0
# 15277  Katsute Kami Datta Kemono-tachi e          0.0  ...       NaN         1.0
#
# ...

# %%
popular_anime = anime_df.iloc[0:11]
popular_anime
# Out:
#     animeID  ...                                            related
# 0         1  ...  {'Adaptation': [{'mal_id': 173, 'type': 'manga...
# 1         5  ...  {'Parent story': [{'mal_id': 1, 'type': 'anime...
# 2         6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 3         7  ...                                                 {}
# 4         8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
# 5        16  ...  {'Adaptation': [{'mal_id': 1009, 'type': 'mang...
# 6        17  ...  {'Adaptation': [{'mal_id': 4147, 'type': 'mang...
# 7        18  ...  {'Adaptation': [{'mal_id': 375, 'type': 'manga...
# 8        19  ...  {'Adaptation': [{'mal_id': 1, 'type': 'manga',...
# 9        20  ...  {'Adaptation': [{'mal_id': 11, 'type': 'manga'...
# 10       21  ...  {'Adaptation': [{'mal_id': 13, 'type': 'manga'...
#
# [11 rows x 27 columns]

# %%
manga_based = popular_anime.loc[[False, False, True, False, True, True, True, True, True, True, True]]
manga_based
# Out:
#     animeID  ...                                            related
# 2         6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 4         8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
# 5        16  ...  {'Adaptation': [{'mal_id': 1009, 'type': 'mang...
# 6        17  ...  {'Adaptation': [{'mal_id': 4147, 'type': 'mang...
# 7        18  ...  {'Adaptation': [{'mal_id': 375, 'type': 'manga...
# 8        19  ...  {'Adaptation': [{'mal_id': 1, 'type': 'manga',...
# 9        20  ...  {'Adaptation': [{'mal_id': 11, 'type': 'manga'...
# 10       21  ...  {'Adaptation': [{'mal_id': 13, 'type': 'manga'...
#
# [8 rows x 27 columns]

# %%
popularity_rank = popular_anime.sort_values(by=' popularity', ascending=True)
popularity_rank
# Out:
#     animeID  ...                                            related
# 9        20  ...  {'Adaptation': [{'mal_id': 11, 'type': 'manga'...
# 10       21  ...  {'Adaptation': [{'mal_id': 13, 'type': 'manga'...
# 0         1  ...  {'Adaptation': [{'mal_id': 173, 'type': 'manga...
# 2         6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 8        19  ...  {'Adaptation': [{'mal_id': 1, 'type': 'manga',...
# 1         5  ...  {'Parent story': [{'mal_id': 1, 'type': 'anime...
# 5        16  ...  {'Adaptation': [{'mal_id': 1009, 'type': 'mang...
# 3         7  ...                                                 {}
# 7        18  ...  {'Adaptation': [{'mal_id': 375, 'type': 'manga...
# 6        17  ...  {'Adaptation': [{'mal_id': 4147, 'type': 'mang...
# 4         8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
#
# [11 rows x 27 columns]

# %%
popularity_rank.head(10)
# Out:
#                                            name  ...   favorites
# 15277         Katsute Kami Datta Kemono-tachi e  ...         1.0
# 13567                     PANDORA VOXX complete  ...         0.0
# 13183                  RunningMan The Animation  ...         2.0
# 13073                   Cyborg 009 x NTT DoCoMo  ...         0.0
# 13007          Jumbagi: Hanbandoui gongryong 3D  ...         0.0
# 12981                                   THE END  ...         0.0
# 12943                        Koi wo Shita no wa  ...         5.0
# 12942                            Speed of Youth  ...         5.0
# 12604  Noah's animal Clinic medical record book  ...         0.0
# 11890                    Chii-chan no Kageokuri  ...         0.0
#
# [10 rows x 6 columns]

# %%
popular_anime = anime_df[[' name',' popularity',' status', ' score',' episodes',' favorites']]
popularity_rank = popular_anime.sort_values(by=' popularity', ascending=True)
popularity_rank.head(10)
# Out:
#                                            name  ...   favorites
# 15277         Katsute Kami Datta Kemono-tachi e  ...         1.0
# 13567                     PANDORA VOXX complete  ...         0.0
# 13183                  RunningMan The Animation  ...         2.0
# 13073                   Cyborg 009 x NTT DoCoMo  ...         0.0
# 13007          Jumbagi: Hanbandoui gongryong 3D  ...         0.0
# 12981                                   THE END  ...         0.0
# 12943                        Koi wo Shita no wa  ...         5.0
# 12942                            Speed of Youth  ...         5.0
# 12604  Noah's animal Clinic medical record book  ...         0.0
# 11890                    Chii-chan no Kageokuri  ...         0.0
#
# [10 rows x 6 columns]

# %% [markdown]
# ### Central Tendencies

# %% [markdown]
# ### Central Tendecies & Data Splicing

# %%
anime_df.columns
# Out:
# Index(['animeID', ' name', ' title_english', ' title_japanese',
#        ' title_synonyms', ' type', ' source', ' producers', ' genre',
#        ' studio', ' episodes', ' status', ' airing', ' aired', ' duration',
#        ' rating', ' score', ' scored_by', ' rank', ' popularity', ' members',
#        ' favorites', ' synopsis', ' background', ' premiered', ' broadcast',
#        ' related'],
#       dtype='object')

# %%
anime_ranks = anime_df[[' name', ' score', ' rating']]
anime_ranks
# Out:
#                                     name  ...                          rating
# 0                           Cowboy Bebop  ...  R - 17+ (violence & profanity)
# 1        Cowboy Bebop: Tengoku no Tobira  ...  R - 17+ (violence & profanity)
# 2                                 Trigun  ...       PG-13 - Teens 13 or older
# 3                     Witch Hunter Robin  ...       PG-13 - Teens 13 or older
# 4                         Bouken Ou Beet  ...                   PG - Children
# ...                                  ...  ...                             ...
# 15273                           Beastars  ...                            None
# 15274            Mairimashita! Iruma-kun  ...                            None
# 15275             Karrimor Mountain Club  ...                    G - All Ages
# 15276                    Kanata no Astra  ...                            None
# 15277  Katsute Kami Datta Kemono-tachi e  ...                            None
#
# [15278 rows x 3 columns]

# %%
anime_ranks = anime_df.iloc[0:200]
anime_ranks
# Out:
#      animeID  ...                                            related
# 0          1  ...  {'Adaptation': [{'mal_id': 173, 'type': 'manga...
# 1          5  ...  {'Parent story': [{'mal_id': 1, 'type': 'anime...
# 2          6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 3          7  ...                                                 {}
# 4          8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
# ..       ...  ...                                                ...
# 195      241  ...  {'Adaptation': [{'mal_id': 325, 'type': 'manga...
# 196      242  ...  {'Adaptation': [{'mal_id': 1092, 'type': 'mang...
# 197      245  ...  {'Adaptation': [{'mal_id': 336, 'type': 'manga...
# 198      246  ...  {'Adaptation': [{'mal_id': 14, 'type': 'manga'...
# 199      247  ...  {'Adaptation': [{'mal_id': 1146, 'type': 'mang...
#
# [200 rows x 27 columns]

# %%
anime_studio = anime_df.groupby(' studio')
anime_studio.first()
# Out:
#                                          animeID  ...                                            related
#  studio                                           ...
# ["Brain's Base", 'Marvy Jack']              5341  ...  {'Adaptation': [{'mal_id': 9115, 'type': 'mang...
# ["Brain's Base", 'Platinum Vision']        31229  ...  {'Adaptation': [{'mal_id': 29887, 'type': 'man...
# ["Brain's Base", 'Studio A-CAT']           28377  ...                                                 {}
# ["Brain's Base"]                             489  ...  {'Adaptation': [{'mal_id': 1690, 'type': 'mang...
# ["Children's Playground Entertainment"]    38669  ...  {'Prequel': [{'mal_id': 33037, 'type': 'anime'...
# ...                                          ...  ...                                                ...
# ['production doA']                         33280  ...  {'Prequel': [{'mal_id': 29787, 'type': 'anime'...
# ...

# %%
## Summing
anime_df[' episodes'].sum()
# Out:
# 172753.0

# %%
## Average
anime_df[' episodes'].mean()
# Out:
# 11.726377952755906

# %%
## Standard Deviation
anime_df[' episodes'].std()
# Out:
# 49.93923130158916

# %%
## Summing
anime_df[' score'].sum()
# Out:
# 92872.45999999999

# %%
## Average
anime_df[' score'].mean()
# Out:
# 6.284508052510523

# %%
## StdDev
anime_df[' score'].std()
# Out:
# 1.0733490740006337

# %%
## Summing
anime_df[' popularity'].mean()
# Out:
# 7741.99129182217

# %%
## StdDev
anime_df[' popularity'].std()
# Out:
# 4482.32303508445

# %% [markdown]
# ## Data Visualization

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
visual_anime = anime_df.head(150)
visual_anime
# Out:
#      animeID  ...                                            related
# 0          1  ...  {'Adaptation': [{'mal_id': 173, 'type': 'manga...
# 1          5  ...  {'Parent story': [{'mal_id': 1, 'type': 'anime...
# 2          6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 3          7  ...                                                 {}
# 4          8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
# ..       ...  ...                                                ...
# 145      183  ...  {'Adaptation': [{'mal_id': 52, 'type': 'manga'...
# 146      184  ...                                                 {}
# 147      186  ...  {'Adaptation': [{'mal_id': 375, 'type': 'manga...
# 148      187  ...  {'Adaptation': [{'mal_id': 375, 'type': 'manga...
# 149      188  ...  {'Sequel': [{'mal_id': 4561, 'type': 'anime', ...
#
# [150 rows x 27 columns]

# %%
visual_anime.plot(' episodes')

# %%
visual_anime.plot.bar(' score')

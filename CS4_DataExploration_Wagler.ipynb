# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikkuchan/AIDA-Group8/blob/main/CS4_DataExploration_Wagler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
anime_df = pd.read_csv("Anime.csv")

# %%
anime_df
# Out:
#       animeID  ...                                            related
# 0           1  ...  {'Adaptation': [{'mal_id': 173, 'type': 'manga...
# 1           5  ...  {'Parent story': [{'mal_id': 1, 'type': 'anime...
# 2           6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 3           7  ...                                                 {}
# 4           8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
# ...       ...  ...                                                ...
# 4809     7456  ...  {'Sequel': [{'mal_id': 2432, 'type': 'anime', ...
# 4810     7458  ...  {'Adaptation': [{'mal_id': 69341, 'type': 'man...
# 4811     7459  ...                                                 {}
# 4812     7461  ...  {'Parent story': [{'mal_id': 7547, 'type': 'an...
# 4813     7463  ...                                                NaN
#
# [4814 rows x 27 columns]

# %%
anime_df.head(5)
# Out:
#    animeID  ...                                            related
# 0        1  ...  {'Adaptation': [{'mal_id': 173, 'type': 'manga...
# 1        5  ...  {'Parent story': [{'mal_id': 1, 'type': 'anime...
# 2        6  ...  {'Adaptation': [{'mal_id': 703, 'type': 'manga...
# 3        7  ...                                                 {}
# 4        8  ...  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...
#
# [5 rows x 27 columns]

# %%
anime_df.tail(5)
# Out:
#       animeID  ...                                            related
# 4809     7456  ...  {'Sequel': [{'mal_id': 2432, 'type': 'anime', ...
# 4810     7458  ...  {'Adaptation': [{'mal_id': 69341, 'type': 'man...
# 4811     7459  ...                                                 {}
# 4812     7461  ...  {'Parent story': [{'mal_id': 7547, 'type': 'an...
# 4813     7463  ...                                                NaN
#
# [5 rows x 27 columns]

# %%
anime_df.describe()
# Out:
#            animeID     episodes  ...       members      favorites
# count  4814.000000  4800.000000  ...  4.808000e+03    4808.000000
# mean   3129.458247    15.824583  ...  2.828362e+04     500.018303
# std    2057.791222    45.101853  ...  8.838861e+04    3838.451037
# min       1.000000     1.000000  ...  1.440000e+02       0.000000
# 25%    1411.250000     1.000000  ...  1.320250e+03       2.000000
# 50%    2775.500000     3.000000  ...  3.789500e+03       8.000000
# 75%    4774.750000    23.250000  ...  1.643250e+04      49.000000
# max    7463.000000  1787.000000  ...  1.610561e+06  120331.000000
#
# [8 rows x 8 columns]

# %%
anime_df.dtypes
# Out:
# animeID              int64
#  name               object
#  title_english      object
#  title_japanese     object
#  title_synonyms     object
#  type               object
#  source             object
#  producers          object
#  genre              object
#  studio             object
#  episodes          float64
#  status             object
#  airing             object
#  aired              object
#  duration           object
#  rating             object
#  score             float64
#  scored_by         float64
#  rank              float64
#  popularity        float64
#  members           float64
#  favorites         float64
#  synopsis           object
#  background         object
#  premiered          object
#  broadcast          object
#  related            object
# dtype: object

# %%
#features of the dataset 
anime_df.columns
# Out:
# Index(['animeID', ' name', ' title_english', ' title_japanese',
#        ' title_synonyms', ' type', ' source', ' producers', ' genre',
#        ' studio', ' episodes', ' status', ' airing', ' aired', ' duration',
#        ' rating', ' score', ' scored_by', ' rank', ' popularity', ' members',
#        ' favorites', ' synopsis', ' background', ' premiered', ' broadcast',
#        ' related'],
#       dtype='object')

# %%
anime_df[' episodes'].sum()
# Out:
# 75958.0

# %%
#Data Splicing
popular_anime = anime_df[[' name',' popularity',' status', ' score',' episodes',' favorites']]
popular_anime
# Out:
#                                                name  ...   favorites
# 0                                      Cowboy Bebop  ...     43460.0
# 1                   Cowboy Bebop: Tengoku no Tobira  ...       776.0
# 2                                            Trigun  ...     10432.0
# 3                                Witch Hunter Robin  ...       537.0
# 4                                    Bouken Ou Beet  ...        14.0
# ...                                             ...  ...         ...
# 4809                                Discipline Zero  ...        37.0
# 4810                Watashi no Shiranai Mesu no Kao  ...        22.0
# 4811   The Collected Animations of ICAF (2001-2006)  ...         0.0
# 4812  Komaneko no Christmas: Maigo ni Natta Present  ...         0.0
# 4813                                 Weiß Survive R  ...         NaN
#
# [4814 rows x 6 columns]

# %%
popularity_rank = popular_anime.sort_values(by=' popularity', ascending=True)
popularity_rank
# Out:
#                                   name   popularity  ...  episodes   favorites
# 1311                        Death Note          1.0  ...      37.0     96146.0
# 3769  Fullmetal Alchemist: Brotherhood          4.0  ...      64.0    120331.0
# 4433                      Angel Beats!          8.0  ...      13.0     38504.0
# 9                               Naruto         10.0  ...     220.0     39356.0
# 1349   Code Geass: Hangyaku no Lelouch         11.0  ...      25.0     68684.0
# ...                                ...          ...  ...       ...         ...
# 3733                               404          NaN  ...       NaN         NaN
# 3735                               404          NaN  ...       NaN         NaN
# 3741                               404          NaN  ...       NaN         NaN
# 3743                               404          NaN  ...       NaN         NaN
# 4813                    Weiß Survive R          NaN  ...       NaN         NaN
#
# [4814 rows x 6 columns]

# %%
popularity_rank.head(10)
# Out:
#                                   name   popularity  ...  episodes   favorites
# 1311                        Death Note          1.0  ...      37.0     96146.0
# 3769  Fullmetal Alchemist: Brotherhood          4.0  ...      64.0    120331.0
# 4433                      Angel Beats!          8.0  ...      13.0     38504.0
# 9                               Naruto         10.0  ...     220.0     39356.0
# 1349   Code Geass: Hangyaku no Lelouch         11.0  ...      25.0     68684.0
# 3386                         Toradora!         13.0  ...      25.0     38471.0
# 182                         Elfen Lied         18.0  ...      13.0     20990.0
# 4504                        Fairy Tail         19.0  ...     175.0     40060.0
# 1480                Naruto: Shippuuden         21.0  ...     500.0     48972.0
# 216                             Bleach         22.0  ...     366.0     42878.0
#
# [10 rows x 6 columns]

# %%
popular_anime = anime_df[[' name',' popularity',' status', ' score',' episodes',' favorites']]
popularity_rank = popular_anime.sort_values(by=' popularity', ascending=True)
popularity_rank.head(10)
# Out:
#                                   name   popularity  ...  episodes   favorites
# 1311                        Death Note          1.0  ...      37.0     96146.0
# 3769  Fullmetal Alchemist: Brotherhood          4.0  ...      64.0    120331.0
# 4433                      Angel Beats!          8.0  ...      13.0     38504.0
# 9                               Naruto         10.0  ...     220.0     39356.0
# 1349   Code Geass: Hangyaku no Lelouch         11.0  ...      25.0     68684.0
# 3386                         Toradora!         13.0  ...      25.0     38471.0
# 182                         Elfen Lied         18.0  ...      13.0     20990.0
# 4504                        Fairy Tail         19.0  ...     175.0     40060.0
# 1480                Naruto: Shippuuden         21.0  ...     500.0     48972.0
# 216                             Bleach         22.0  ...     366.0     42878.0
#
# [10 rows x 6 columns]
